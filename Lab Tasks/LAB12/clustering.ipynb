# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# %%
datasets = np.array([[ 0.31424733, -1.52069328],
 [ 2.67211361, -0.87792143],
 [ 0.35214163,  1.20032824],
 [ 0.70534207,  1.54587698],
 [-1.30378736,  2.90442946],
 [-1.7526881,   1.42792581],
 [-1.63107581,  0.45274937],
 [ 0.46786792 ,-2.25643484],
 [-2.71845914  ,1.61561416],
 [ 0.75481428 , 1.25603317],
 [-0.66059695, -2.13679473],
 [-1.91822203 , 1.46725633],
 [-1.45351763 ,-1.40389661],
 [ 0.21238683  ,2.5321107 ],
 [-0.32261607 ,-0.61005923],
 [ 2.57784856 ,-1.72534884],
 [ 2.28252032 ,-0.70577662],
 [ 1.54027514 ,-2.06946044],
 [-1.05050363 , 0.7087892 ],
 [-0.26643753, -1.69620941]])

# %%
points= datasets

# %%
from sklearn.cluster import KMeans

# %%
kmeans= KMeans(n_clusters=2)

# %%
kmeans.fit(points)
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
plt.scatter(datasets[:,0],datasets[:,1])

# %%
clusters= kmeans.cluster_centers_

# %%
print(clusters)
# Out:
# [[ 0.71517047 -1.50025954]
#  [-0.83500513  1.51111134]]

# %%
y= kmeans.fit_predict(points)
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
y
# Out:
# array([0, 0, 1, 1, 1, 1, 1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 0, 0, 1, 0],
#       dtype=int32)

# %%
plt.scatter(points[y == 0,0], points[y == 0,1], s=5, color= 'Red')

# %%
plt.scatter(points[y == 0,0], points[y == 0,1], s=50, color= 'Red')
plt.scatter(points[y == 1,0], points[y == 1,1], s=50, color= 'Green')

# %%
plt.scatter(points[y == 0,0], points[y == 0,1], s=50, color= 'Red')
plt.scatter(points[y == 1,0], points[y == 1,1], s=50, color= 'Green')
plt.scatter(points[y == 2,0], points[y == 2,1], s=50, color= 'Yellow')

# %%
plt.scatter(points[y == 0,0], points[y == 0,1], s=50, color= 'Red')
plt.scatter(points[y == 1,0], points[y == 1,1], s=50, color= 'Green')
plt.scatter(points[y == 2,0], points[y == 2,1], s=50, color= 'Yellow')
plt.scatter(points[y == 3,0], points[y == 3,1], s=50, color= 'Cyan')

# %%
plt.scatter(points[y == 0,0], points[y == 0,1], s=50, color= 'Red')
plt.scatter(points[y == 1,0], points[y == 1,1], s=50, color= 'Green')
plt.scatter(points[y == 2,0], points[y == 2,1], s=50, color= 'Yellow')
plt.scatter(points[y == 3,0], points[y == 3,1], s=50, color= 'Cyan')
plt.scatter(clusters[0][0], clusters[0][1], marker='*', s=200, color='black')

# %%
plt.scatter(points[y == 0,0], points[y == 0,1], s=50, color= 'Red')
plt.scatter(points[y == 1,0], points[y == 1,1], s=50, color= 'Green')
plt.scatter(points[y == 2,0], points[y == 2,1], s=50, color= 'Yellow')
plt.scatter(points[y == 3,0], points[y == 3,1], s=50, color= 'Cyan')
plt.scatter(clusters[0][0], clusters[0][1], marker='*', s=200, color='black')
plt.scatter(clusters[1][0], clusters[1][1], marker='*', s=200, color='black')
plt.scatter(clusters[2][0], clusters[2][1], marker='*', s=200, color='black')
plt.scatter(clusters[3][0], clusters[3][1], marker='*', s=200, color='black')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 7
#       5 plt.scatter(clusters[0][0], clusters[0][1], marker='*', s=200, color='black')
#       6 plt.scatter(clusters[1][0], clusters[1][1], marker='*', s=200, color='black')
# ----> 7 plt.scatter(clusters[2][0], clusters[2][1], marker='*', s=200, color='black')
#       8 plt.scatter(clusters[3][0], clusters[3][1], marker='*', s=200, color='black')
#
# IndexError: index 2 is out of bounds for axis 0 with size 2
